# %%
import numpy as np
arr = np.genfromtxt('Day13.txt',delimiter = ',',dtype=np.int64)

# %%
def indexing(listt,index):
    inxlist = []
    global arr1
    for i, ss in enumerate(listt):
        if ss == '0': #position mode
            inxlist.append(arr1[index+i+1])
        elif ss =='1': #immediate mode
            inxlist.append(index+i+1)
        else: #ss == '2'
            global base
            inxlist.append(arr1[index+i+1]+base)
    return inxlist

def arrOdict(inxlist):
    global arr1
    global lgmem
    vallist = []
    for inx in inxlist:
        if inx > (len(arr1)-1):
            if inx not in lgmem.keys():
                lgmem[inx] = 0
                vallist.append(lgmem[inx])
            else:
                vallist.append(lgmem[inx])
        else:
            vallist.append(arr1[inx])
    return vallist

def setequal(inxequal,num):
    global arr1
    global lgmem
    if inxequal > (len(arr1)-1):
        lgmem[inxequal] = num
    else:
        arr1[inxequal] = num
    return None

def opcodeAct(index,inxlist,opcode):
    global arr1
    global inpt
    vallist = arrOdict(inxlist)
    if opcode == 1:
        setequal(inxlist[2],vallist[0] + vallist[1])
        index += 4
    elif opcode == 2:
        setequal(inxlist[2],vallist[0] * vallist[1])
        index += 4
    elif opcode == 4:
        global carepack
        carepack.append(vallist[0])
        index += 2
    elif opcode == 3:
        setequal(inxlist[0],inpt)
        index += 2
    elif opcode == 5:
        if vallist[0]: #If non-zero is true
            index = vallist[1]
        else:
            index += 3
    elif opcode == 6:
        if not vallist[0]:
            index = vallist[1]
        else:
            index += 3
    elif opcode == 7:
        if vallist[0] < vallist[1]:
            setequal(inxlist[2],1)
        else:
            setequal(inxlist[2],0)
        index += 4
    elif opcode == 8:
        if vallist[0] == vallist[1]:
            setequal(inxlist[2],1)
        else:
            setequal(inxlist[2],0)
        index += 4
    elif opcode == 9:
        global base
        base += vallist[0]
        index += 2
    return index

def day9(arr):
    global arr1
    global inpt
    global carepack
    arr1 = arr.copy()
    index = 2
    paddlexy = []
    ballxy = []
    while arr1[index] != 99:
        if arr1[index] in [1,2,7,8]:
            index = opcodeAct(index,arr1[index+1:index+4],arr1[index])
        elif arr1[index] in [5,6]:
            index = opcodeAct(index,arr1[index+1:index+3],arr1[index])
        elif arr1[index] in [3,4,9]:
            index = opcodeAct(index,arr1[index+1:index+2],arr1[index])
        else: #5 digit opcode
            s = str(arr1[index])
            s = s.rjust(5,'0')
            s = s[::-1]
            if int(s[0]) in [1,2,7,8]:
                inxlist = indexing(s[2:],index)
            elif int(s[0]) in [5,6]:
                inxlist = indexing(s[2:4],index)
            elif int(s[0]) in [3,4,9]:
                inxlist = indexing(s[2:3],index)
            index = opcodeAct(index,inxlist,int(s[0]))
        if (len(carepack) > 0) & (len(carepack)%3 == 0):
            if carepack[-1] == 3:
                if len(paddlexy) == 0:
                    paddlexy.append(carepack[-3])
                    paddlexy.append(carepack[-2])
                else:
                    paddlexy[0],paddlexy[1] = carepack[-3],carepack[-2]
            if carepack[-1] == 4:
                if len(ballxy) == 0:
                    ballxy.append(carepack[-3])
                    ballxy.append(carepack[-2])
                else:
                    ballxy[0],ballxy[1] = carepack[-3],carepack[-2]
        if (len(ballxy) > 0) & (len(paddlexy) > 0):
            if ballxy[0] > paddlexy[0]:
                inpt = 1
            elif ballxy[0] < paddlexy[0]:
                inpt = -1
            else:
                inpt = 0
    return None

# %%
base = 0
lgmem = {}
inpt = 0
carepack = []
day9(arr)

# %%
carepackn = np.array(carepack).reshape((len(carepack)//3,3))

# %%
carepackn[np.all((carepackn[:,0:2] == [-1,0]),axis=1)][-1][2]
# Out:
# 15957
